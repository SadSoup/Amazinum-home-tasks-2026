# %% [markdown]
# # Шо на дз треба і не зрозуміло
#
# ## Чисте
#
# ### скріни
#
#
# ### рідмі
# - шо має бути: а)start the server; б)send an image to an endpoint; в)get the result back. (можна перевірку здоров'я)
# - вміст папки app.py, requirements.txt, README.md, example input image, result image, and screenshots/logs.
# - можна додати, які формати читає cv ліба
# ```
# .jpg
# .jpeg
# .png
# .bmp
# .webp
# .tiff
# ```
#
# ### можна потім
#
# - може спитати в них за воркфлов, як то відбувається в продакшині: бо там є, що от ми вибрали гіперпараметри, повчили, евалювали і знов, якщо є велика модель, глибока наприклад, то чи робиться кросвалідація

# %% [markdown]
# # Homework

# %% [markdown]
# Make a simple computer vision solution and deploy it in any form described (API via FastAPI/Flask or Event-driven architecture).
#
# Evaluation criteria:
#
# 1. Script with code of model deployment in chosen form.
# 2. Description of implementation (as `README.md` in the folder of the solution):
#
#     - Overview;
#     - Deployment info;
#     - Installation instruction with requirements.txt;
#     - Modeling info;
#     - Interface description (list of endpoints/event handlers, it's input and output, short description of functionality);
#
# 3. Example of processes (screenshot of communication or logs).
